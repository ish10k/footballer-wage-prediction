# %% [markdown]
# # Predicting footballer player wage based on respective FIFA / EAFC plater stats
#
# The problem we are addressing is correctly evaluating a playe's valuations based on their attributes and ratings. With ever more growing talent in the field, it is vital as a football club to accurately price your players to stay competitive. Our goal is to study & build machine learning models to accurately predict a footballer's value based on a dataset of attributes and ratings.

# %% [markdown]
# # Importing data
#
# We are going to be utilising the [EA Sports FC 24 complete player dataset](https://www.kaggle.com/datasets/stefanoleone992/ea-sports-fc-24-complete-player-dataset/data) from kaggle for player stats and valautions.

# %% [markdown]
# Required Python modules:
# * Pandas - importing and manipulating data

# %%
import pandas as pd
from copy import deepcopy
# instructing pandas to not truncate column widths when displaying data in interactive mode
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

random_state = 42 # Set random state to ensure all random variables can be reproduced
datasets_fp = 'datasets/' # Datasets folder path
df = pd.read_csv(datasets_fp + 'male_players.csv', encoding='unicode_escape')
df
# Out:
# C:\Users\Ishina\AppData\Local\Temp\ipykernel_47832\2854889244.py:9: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(datasets_fp + 'male_players.csv', encoding='unicode_escape')
#         player_id                                             player_url  \
# 0          231747                    /player/231747/kylian-mbappe/240002
# 1          239085                   /player/239085/erling-haaland/240002
# 2          192985                  /player/192985/kevin-de-bruyne/240002
# 3          158023                     /player/158023/lionel-messi/240002
# 4          165153                    /player/165153/karim-benzema/240002
# ...           ...                                                    ...
# 180016     220806   https://sofifa.com/player/220806/ellis-redman/150002
# 180017     225509  https://sofifa.com/player/225509/aaron-collins/150002
# 180018     217591    https://sofifa.com/player/217591/piotr-zemlo/150002
# 180019     222947     https://sofifa.com/player/222947/tom-davies/150002
# 180020     201197   https://sofifa.com/player/201197/paul-tisdale/150002
#
#         fifa_version  fifa_update update_as_of    short_name  \
# 0               24.0          2.0   2023-09-22    K. MbappÃ©
# 1               24.0          2.0   2023-09-22    E. Haaland
# 2               24.0          2.0   2023-09-22  K. De Bruyne
# 3               24.0          2.0   2023-09-22      L. Messi
# 4               24.0          2.0   2023-09-22    K. Benzema
# ...              ...          ...          ...           ...
# 180016          15.0          2.0   2014-09-18     E. Redman
# 180017          15.0          2.0   2014-09-18    A. Collins
# 180018          15.0          2.0   2014-09-18    P. Å»emÅo
# 180019          15.0          2.0   2014-09-18     T. Davies
# 180020          15.0          2.0   2014-09-18    P. Tisdale
#
#                               long_name player_positions  overall  potential  \
# 0                 Kylian MbappÃ© Lottin           ST, LW       91         94
# 1                  Erling Braut Haaland               ST       91         94
# 2                       Kevin De Bruyne          CM, CAM       91         91
# 3       Lionel AndrÃ©s Messi Cuccittini          CF, CAM       90         90
# 4                         Karim Benzema           CF, ST       90         90
# ...                                 ...              ...      ...        ...
# 180016                     Ellis Redman               CB       41         61
# 180017        Aaron Graham John Collins               ST       41         50
# 180018                    Piotr Å»emÅo           LM, LB       40         50
# 180019        Thomas Christopher Davies               CB       40         49
# 180020                     Paul Tisdale          CM, CAM       40         40
#
#           value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 0       181500000.0  230000.0   24  1998-12-20        182         75
# 1       185000000.0  340000.0   22  2000-07-21        195         94
# 2       103000000.0  350000.0   32  1991-06-28        181         75
# 3        41000000.0   23000.0   36  1987-06-24        169         67
# 4        51000000.0   95000.0   35  1987-12-19        185         81
# ...             ...       ...  ...         ...        ...        ...
# 180016      20000.0    2000.0   17  1996-09-26        187         81
# 180017      30000.0    2000.0   17  1997-06-01        178         57
# 180018      15000.0    2000.0   18  1995-07-10        190         76
# 180019      15000.0    2000.0   22  1992-04-18        180         70
# 180020          NaN    2000.0   41  1973-01-14        175         72
#
#         club_team_id            club_name  league_id          league_name  \
# 0               73.0  Paris Saint Germain       16.0              Ligue 1
# 1               10.0      Manchester City       13.0       Premier League
# 2               10.0      Manchester City       13.0       Premier League
# 3           112893.0          Inter Miami       39.0  Major League Soccer
# 4              607.0           Al Ittihad      350.0           Pro League
# ...              ...                  ...        ...                  ...
# 180016      112254.0       Newport County       61.0           League Two
# 180017      112254.0       Newport County       61.0           League Two
# 180018        1873.0       WisÅa KrakÃ³w       66.0          Ekstraklasa
# 180019      112260.0       Fleetwood Town       60.0           League One
# 180020         143.0          Exeter City       61.0           League One
#
#         league_level club_position  club_jersey_number club_loaned_from  \
# 0                1.0            LW                 7.0              NaN
# 1                1.0            ST                 9.0              NaN
# 2                1.0           SUB                17.0              NaN
# 3                1.0            RF                10.0              NaN
# 4                1.0            RS                 9.0              NaN
# ...              ...           ...                 ...              ...
# 180016           4.0           RES                35.0              NaN
# 180017           4.0           RES                39.0              NaN
# 180018           1.0           RES                43.0              NaN
# 180019           3.0           RES                26.0              NaN
# 180020           4.0           RES                17.0              NaN
#
#        club_joined_date  club_contract_valid_until_year  nationality_id  \
# 0            2018-07-01                          2024.0              18
# 1            2022-07-01                          2027.0              36
# 2            2015-08-30                          2025.0               7
# 3            2023-07-16                          2025.0              52
# 4            2023-07-01                          2026.0              18
# ...                 ...                             ...             ...
# 180016       2013-10-22                          2015.0              50
# 180017       2014-08-14                          2015.0              50
# 180018       2012-07-01                          2015.0              37
# 180019       2014-03-11                          2021.0              14
# 180020       2006-06-26                          2015.0              32
#
#        nationality_name  nation_team_id nation_position  nation_jersey_number  \
# 0                France          1335.0              LW                  10.0
# 1                Norway          1352.0              ST                   9.0
# 2               Belgium          1325.0             CAM                   7.0
# 3             Argentina          1369.0              RW                  10.0
# 4                France             NaN             NaN                   NaN
# ...                 ...             ...             ...                   ...
# 180016            Wales             NaN             NaN                   NaN
# 180017            Wales             NaN             NaN                   NaN
# 180018           Poland             NaN             NaN                   NaN
# 180019          England             NaN             NaN                   NaN
# 180020            Malta             NaN             NaN                   NaN
#
#        preferred_foot  weak_foot  skill_moves  international_reputation  \
# 0               Right          4            5                         5
# 1                Left          3            3                         5
# 2               Right          5            4                         5
# 3                Left          4            4                         5
# 4               Right          4            4                         5
# ...               ...        ...          ...                       ...
# 180016          Right          2            2                         1
# 180017          Right          3            3                         1
# 180018           Left          3            2                         1
# 180019          Right          2            2                         1
# 180020          Right          3            2                         1
#
#             work_rate         body_type real_face  release_clause_eur  \
# 0            High/Low            Unique       Yes         349400000.0
# 1         High/Medium            Unique       Yes         356100000.0
# 2         High/Medium            Unique       Yes         190600000.0
# 3             Low/Low            Unique       Yes          61500000.0
# 4       Medium/Medium  Normal (170-185)       Yes          81600000.0
# ...               ...               ...       ...                 ...
# 180016  Medium/Medium     Normal (185+)        No                 NaN
# 180017  Medium/Medium    Lean (170-185)        No                 NaN
# 180018  Medium/Medium     Normal (185+)        No                 NaN
# 180019  Medium/Medium  Normal (170-185)        No                 NaN
# 180020  Medium/Medium    Lean (170-185)        No                 NaN
#
#                                                                                                          player_tags  \
# 0                                             #Speedster, #Dribbler, #Acrobat, #Clinical finisher, #Complete forward
# 1                                #Aerial threat, #Distance shooter, #Strength, #Clinical finisher, #Complete forward
# 2                                           #Dribbler, #Playmaker, #Distance shooter, #Crosser, #Complete midfielder
# 3       #Dribbler, #Playmaker, #FK Specialist, #Acrobat, #Clinical finisher, #Complete midfielder, #Complete forward
# 4                                                    #Poacher, #Aerial threat, #Clinical finisher, #Complete forward
# ...                                                                                                              ...
# 180016                                                                                                           NaN
# 180017                                                                                                           NaN
# 180018                                                                                                           NaN
# 180019                                                                                                           NaN
# 180020                                                                                                           NaN
#
#                                                                               player_traits  \
# 0                                                       Quick Step +, Rapid, Flair, Trivela
# 1                                                     Acrobatic +, Power Header, Quick Step
# 2           Pinged Pass +, Dead Ball, Incisive Pass, Long Ball Pass, Whipped Cross, Trivela
# 3         Technical +, Finesse Shot, Dead Ball, Pinged Pass, Tiki Taka, Quick Step, Trivela
# 4       Finesse Shot +, Dead Ball, Pinged Pass, Tiki Taka, First Touch, Relentless, Trivela
# ...                                                                                     ...
# 180016                                                                                  NaN
# 180017                                                                                  NaN
# 180018                                                                                  NaN
# 180019                                                                                  NaN
# 180020                                                         Injury Prone, Playmaker (AI)
#
#         pace  shooting  passing  dribbling  defending  physic  \
# 0       97.0      90.0     80.0       92.0       36.0    78.0
# 1       89.0      93.0     66.0       80.0       45.0    88.0
# 2       72.0      88.0     94.0       87.0       65.0    78.0
# 3       80.0      87.0     90.0       94.0       33.0    64.0
# 4       79.0      88.0     83.0       87.0       39.0    78.0
# ...      ...       ...      ...        ...        ...     ...
# 180016  66.0      25.0     29.0       30.0       39.0    53.0
# 180017  64.0      41.0     27.0       35.0       27.0    41.0
# 180018  58.0      27.0     35.0       31.0       52.0    68.0
# 180019  72.0      27.0     27.0       30.0       35.0    61.0
# 180020  38.0      36.0     42.0       45.0       31.0    33.0
#
#         attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                       78                   94                          73
# 1                       47                   96                          83
# 2                       95                   85                          55
# 3                       83                   89                          60
# 4                       75                   91                          90
# ...                    ...                  ...                         ...
# 180016                  25                   25                          41
# 180017                  22                   47                          43
# 180018                  49                   24                          57
# 180019                  23                   25                          38
# 180020                  39                   36                          29
#
#         attacking_short_passing  attacking_volleys  skill_dribbling  \
# 0                            86                 84               93
# 1                            77                 90               79
# 2                            94                 83               86
# 3                            91                 86               96
# 4                            89                 88               87
# ...                         ...                ...              ...
# 180016                       36                 25               25
# 180017                       25                 27               29
# 180018                       40                 25               27
# 180019                       32                 29               24
# 180020                       43                 27               46
#
#         skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0                80                 69                  71
# 1                77                 62                  53
# 2                92                 83                  94
# 3                93                 93                  90
# 4                82                 73                  76
# ...             ...                ...                 ...
# 180016           21                 25                  33
# 180017           20                 22                  24
# 180018           24                 21                  34
# 180019           24                 27                  21
# 180020           41                 53                  41
#
#         skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                       92                     97                     97
# 1                       82                     82                     94
# 2                       92                     72                     72
# 3                       93                     87                     74
# 4                       91                     78                     79
# ...                    ...                    ...                    ...
# 180016                  26                     65                     66
# 180017                  30                     60                     68
# 180018                  32                     57                     58
# 180019                  35                     71                     73
# 180020                  44                     35                     41
#
#         movement_agility  movement_reactions  movement_balance  \
# 0                     93                  93                82
# 1                     76                  94                72
# 2                     74                  92                78
# 3                     91                  88                95
# 4                     77                  92                72
# ...                  ...                 ...               ...
# 180016                52                  36                55
# 180017                66                  39                68
# 180018                36                  50                44
# 180019                33                  32                61
# 180020                37                  41                51
#
#         power_shot_power  power_jumping  power_stamina  power_strength  \
# 0                     90             88             88              77
# 1                     94             93             76              93
# 2                     92             72             88              74
# 3                     83             71             70              68
# 4                     87             85             82              82
# ...                  ...            ...            ...             ...
# 180016                22             62             56              52
# 180017                36             51             47              42
# 180018                31             61             74              75
# 180019                39             64             70              63
# 180020                32             39             25              37
#
#         power_long_shots  mentality_aggression  mentality_interceptions  \
# 0                     83                    64                       38
# 1                     86                    87                       43
# 2                     92                    75                       66
# 3                     90                    44                       40
# 4                     81                    63                       39
# ...                  ...                   ...                      ...
# 180016                25                    50                       41
# 180017                36                    30                       25
# 180018                25                    44                       47
# 180019                22                    44                       34
# 180020                38                    32                       35
#
#         mentality_positioning  mentality_vision  mentality_penalties  \
# 0                          93                83                   84
# 1                          96                74                   84
# 2                          88                95                   83
# 3                          91                92                   75
# 4                          92                90                   85
# ...                       ...               ...                  ...
# 180016                     25                22                   31
# 180017                     41                39                   47
# 180018                     38                21                   31
# 180019                     27                25                   21
# 180020                     43                41                   55
#
#         mentality_composure  defending_marking_awareness  \
# 0                      88.0                           26
# 1                      87.0                           38
# 2                      88.0                           66
# 3                      96.0                           20
# 4                      90.0                           43
# ...                     ...                          ...
# 180016                  NaN                           38
# 180017                  NaN                           25
# 180018                  NaN                           54
# 180019                  NaN                           36
# 180020                  NaN                           27
#
#         defending_standing_tackle  defending_sliding_tackle  \
# 0                              34                        32
# 1                              47                        29
# 2                              70                        53
# 3                              35                        24
# 4                              24                        18
# ...                           ...                       ...
# 180016                         40                        35
# 180017                         25                        25
# 180018                         52                        51
# 180019                         34                        35
# 180020                         34                        29
#
#         goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       13                     5                    7
# 1                        7                    14                   13
# 2                       15                    13                    5
# 3                        6                    11                   15
# 4                       13                    11                    5
# ...                    ...                   ...                  ...
# 180016                  12                     6                   15
# 180017                  13                    11                   12
# 180018                   8                    14                    7
# 180019                  15                    13                    6
# 180020                   5                     6                   14
#
#         goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 0                            11                     6                NaN
# 1                            11                     7                NaN
# 2                            10                    13                NaN
# 3                            14                     8                NaN
# 4                             5                     7                NaN
# ...                         ...                   ...                ...
# 180016                        8                     6                NaN
# 180017                       15                    11                NaN
# 180018                       10                     9                NaN
# 180019                       11                     9                NaN
# 180020                        8                    13                NaN
#
#           ls    st    rs    lw  lf  cf  rf    rw   lam   cam   ram    lm  \
# 0       90+3  90+3  90+3    91  91  91  91    91  89+3  89+3  89+3  89+3
# 1       90+3  90+3  90+3    82  86  86  86    82  82+3  82+3  82+3  79+3
# 2       83+3  83+3  83+3    87  88  88  88    87  89+2  89+2  89+2  88+3
# 3       85+3  85+3  85+3    90  89  89  89    90  91-1  91-1  91-1  89+1
# 4       88+2  88+2  88+2    86  89  89  89    86  88+2  88+2  88+2  86+3
# ...      ...   ...   ...   ...  ..  ..  ..   ...   ...   ...   ...   ...
# 180016    32    32    32    33  30  30  30    33    30    30    30    34
# 180017    41    41    41    37  39  39  39    37    37    37    37    35
# 180018    38    38    38    38  35  35  35    38    33    33    33    40
# 180019    35    35    35    33  33  33  33    33    31    31    31    34
# 180020    38    38    38  41-1  40  40  40  41-1  41-1  41-1  41-1  41-1
#
#          lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 0       81+3  81+3  81+3  89+3  68+3  63+3  63+3  63+3  68+3  63+3  54+3
# 1       74+3  74+3  74+3  79+3  62+3  63+3  63+3  63+3  62+3  60+3  62+3
# 2       90+1  90+1  90+1  88+3  79+3  80+3  80+3  80+3  79+3  75+3  70+3
# 3       85+3  85+3  85+3  89+1  64+3  63+3  63+3  63+3  64+3  59+3  49+3
# 4       82+3  82+3  82+3  86+3  64+3  64+3  64+3  64+3  64+3  60+3  55+3
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 180016    32    32    32    34    37    38    38    38    37    40    41
# 180017    32    32    32    35    31    30    30    30    31    32    31
# 180018    38    38    38    40    48    46    46    46    48  51-1  53-3
# 180019    31    31    31    34    37    36    36    36    37    39    40
# 180020    40    40    40  41-1    36    37    37    37    36    34    33
#
#           cb   rcb    rb    gk
# 0       54+3  54+3  63+3  18+3
# 1       62+3  62+3  60+3  19+3
# 2       70+3  70+3  75+3  21+3
# 3       49+3  49+3  59+3  19+3
# 4       55+3  55+3  60+3  18+3
# ...      ...   ...   ...   ...
# 180016    41    41    40    10
# 180017    31    31    32    14
# 180018  53-3  53-3  51-1    12
# 180019    40    40    39    13
# 180020    33    33    34    10
#
# [180021 rows x 109 columns]

# %% [markdown]
# Let's have a quick look at the dataframe

# %%
df.head(5) # first 5 rows
# Out:
#    player_id                             player_url  fifa_version  \
# 0     231747    /player/231747/kylian-mbappe/240002          24.0
# 1     239085   /player/239085/erling-haaland/240002          24.0
# 2     192985  /player/192985/kevin-de-bruyne/240002          24.0
# 3     158023     /player/158023/lionel-messi/240002          24.0
# 4     165153    /player/165153/karim-benzema/240002          24.0
#
#    fifa_update update_as_of    short_name                        long_name  \
# 0          2.0   2023-09-22    K. MbappÃ©            Kylian MbappÃ© Lottin
# 1          2.0   2023-09-22    E. Haaland             Erling Braut Haaland
# 2          2.0   2023-09-22  K. De Bruyne                  Kevin De Bruyne
# 3          2.0   2023-09-22      L. Messi  Lionel AndrÃ©s Messi Cuccittini
# 4          2.0   2023-09-22    K. Benzema                    Karim Benzema
#
#   player_positions  overall  potential    value_eur  wage_eur  age  \
# 0           ST, LW       91         94  181500000.0  230000.0   24
# 1               ST       91         94  185000000.0  340000.0   22
# 2          CM, CAM       91         91  103000000.0  350000.0   32
# 3          CF, CAM       90         90   41000000.0   23000.0   36
# 4           CF, ST       90         90   51000000.0   95000.0   35
#
#           dob  height_cm  weight_kg  club_team_id            club_name  \
# 0  1998-12-20        182         75          73.0  Paris Saint Germain
# 1  2000-07-21        195         94          10.0      Manchester City
# 2  1991-06-28        181         75          10.0      Manchester City
# 3  1987-06-24        169         67      112893.0          Inter Miami
# 4  1987-12-19        185         81         607.0           Al Ittihad
#
#    league_id          league_name  league_level club_position  \
# 0       16.0              Ligue 1           1.0            LW
# 1       13.0       Premier League           1.0            ST
# 2       13.0       Premier League           1.0           SUB
# 3       39.0  Major League Soccer           1.0            RF
# 4      350.0           Pro League           1.0            RS
#
#    club_jersey_number club_loaned_from club_joined_date  \
# 0                 7.0              NaN       2018-07-01
# 1                 9.0              NaN       2022-07-01
# 2                17.0              NaN       2015-08-30
# 3                10.0              NaN       2023-07-16
# 4                 9.0              NaN       2023-07-01
#
#    club_contract_valid_until_year  nationality_id nationality_name  \
# 0                          2024.0              18           France
# 1                          2027.0              36           Norway
# 2                          2025.0               7          Belgium
# 3                          2025.0              52        Argentina
# 4                          2026.0              18           France
#
#    nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 0          1335.0              LW                  10.0          Right
# 1          1352.0              ST                   9.0           Left
# 2          1325.0             CAM                   7.0          Right
# 3          1369.0              RW                  10.0           Left
# 4             NaN             NaN                   NaN          Right
#
#    weak_foot  skill_moves  international_reputation      work_rate  \
# 0          4            5                         5       High/Low
# 1          3            3                         5    High/Medium
# 2          5            4                         5    High/Medium
# 3          4            4                         5        Low/Low
# 4          4            4                         5  Medium/Medium
#
#           body_type real_face  release_clause_eur  \
# 0            Unique       Yes         349400000.0
# 1            Unique       Yes         356100000.0
# 2            Unique       Yes         190600000.0
# 3            Unique       Yes          61500000.0
# 4  Normal (170-185)       Yes          81600000.0
#
#                                                                                                     player_tags  \
# 0                                        #Speedster, #Dribbler, #Acrobat, #Clinical finisher, #Complete forward
# 1                           #Aerial threat, #Distance shooter, #Strength, #Clinical finisher, #Complete forward
# 2                                      #Dribbler, #Playmaker, #Distance shooter, #Crosser, #Complete midfielder
# 3  #Dribbler, #Playmaker, #FK Specialist, #Acrobat, #Clinical finisher, #Complete midfielder, #Complete forward
# 4                                               #Poacher, #Aerial threat, #Clinical finisher, #Complete forward
#
#                                                                          player_traits  \
# 0                                                  Quick Step +, Rapid, Flair, Trivela
# 1                                                Acrobatic +, Power Header, Quick Step
# 2      Pinged Pass +, Dead Ball, Incisive Pass, Long Ball Pass, Whipped Cross, Trivela
# 3    Technical +, Finesse Shot, Dead Ball, Pinged Pass, Tiki Taka, Quick Step, Trivela
# 4  Finesse Shot +, Dead Ball, Pinged Pass, Tiki Taka, First Touch, Relentless, Trivela
#
#    pace  shooting  passing  dribbling  defending  physic  attacking_crossing  \
# 0  97.0      90.0     80.0       92.0       36.0    78.0                  78
# 1  89.0      93.0     66.0       80.0       45.0    88.0                  47
# 2  72.0      88.0     94.0       87.0       65.0    78.0                  95
# 3  80.0      87.0     90.0       94.0       33.0    64.0                  83
# 4  79.0      88.0     83.0       87.0       39.0    78.0                  75
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   94                          73                       86
# 1                   96                          83                       77
# 2                   85                          55                       94
# 3                   89                          60                       91
# 4                   91                          90                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 84               93           80                 69
# 1                 90               79           77                 62
# 2                 83               86           92                 83
# 3                 86               96           93                 93
# 4                 88               87           82                 73
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  71                  92                     97
# 1                  53                  82                     82
# 2                  94                  92                     72
# 3                  90                  93                     87
# 4                  76                  91                     78
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     97                93                  93
# 1                     94                76                  94
# 2                     72                74                  92
# 3                     74                91                  88
# 4                     79                77                  92
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                82                90             88             88
# 1                72                94             93             76
# 2                78                92             72             88
# 3                95                83             71             70
# 4                72                87             85             82
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              77                83                    64
# 1              93                86                    87
# 2              74                92                    75
# 3              68                90                    44
# 4              82                81                    63
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       38                     93                83
# 1                       43                     96                74
# 2                       66                     88                95
# 3                       40                     91                92
# 4                       39                     92                90
#
#    mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                   84                 88.0                           26
# 1                   84                 87.0                           38
# 2                   83                 88.0                           66
# 3                   75                 96.0                           20
# 4                   85                 90.0                           43
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         34                        32                  13
# 1                         47                        29                   7
# 2                         70                        53                  15
# 3                         35                        24                   6
# 4                         24                        18                  13
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                     5                    7                       11
# 1                    14                   13                       11
# 2                    13                    5                       10
# 3                    11                   15                       14
# 4                    11                    5                        5
#
#    goalkeeping_reflexes  goalkeeping_speed    ls    st    rs  lw  lf  cf  rf  \
# 0                     6                NaN  90+3  90+3  90+3  91  91  91  91
# 1                     7                NaN  90+3  90+3  90+3  82  86  86  86
# 2                    13                NaN  83+3  83+3  83+3  87  88  88  88
# 3                     8                NaN  85+3  85+3  85+3  90  89  89  89
# 4                     7                NaN  88+2  88+2  88+2  86  89  89  89
#
#    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm  \
# 0  91  89+3  89+3  89+3  89+3  81+3  81+3  81+3  89+3  68+3  63+3  63+3  63+3
# 1  82  82+3  82+3  82+3  79+3  74+3  74+3  74+3  79+3  62+3  63+3  63+3  63+3
# 2  87  89+2  89+2  89+2  88+3  90+1  90+1  90+1  88+3  79+3  80+3  80+3  80+3
# 3  90  91-1  91-1  91-1  89+1  85+3  85+3  85+3  89+1  64+3  63+3  63+3  63+3
# 4  86  88+2  88+2  88+2  86+3  82+3  82+3  82+3  86+3  64+3  64+3  64+3  64+3
#
#     rwb    lb   lcb    cb   rcb    rb    gk
# 0  68+3  63+3  54+3  54+3  54+3  63+3  18+3
# 1  62+3  60+3  62+3  62+3  62+3  60+3  19+3
# 2  79+3  75+3  70+3  70+3  70+3  75+3  21+3
# 3  64+3  59+3  49+3  49+3  49+3  59+3  19+3
# 4  64+3  60+3  55+3  55+3  55+3  60+3  18+3

# %% [markdown]
# Let's do a quick analysis of the data and it's columns using the pandas describe() method

# %%
df.describe(include='all') # using include='all' to show us all columns
# Out:
#             player_id                           player_url   fifa_version  \
# count   180021.000000                               180021  180021.000000
# unique            NaN                               180021            NaN
# top               NaN  /player/231747/kylian-mbappe/240002            NaN
# freq              NaN                                    1            NaN
# mean    217326.670294                                  NaN      19.621450
# std      35215.749284                                  NaN       2.838621
# min          2.000000                                  NaN      15.000000
# 25%     200759.000000                                  NaN      17.000000
# 50%     222734.000000                                  NaN      20.000000
# 75%     239858.000000                                  NaN      22.000000
# max     278145.000000                                  NaN      24.000000
#
#         fifa_update update_as_of     short_name   long_name player_positions  \
# count      180021.0       180021         180021      180021           180021
# unique          NaN           10          47272       52892             2031
# top             NaN   2021-09-23  J. RodrÃ­guez  Danny Ward               CB
# freq            NaN        19239             90          20            22479
# mean            2.0          NaN            NaN         NaN              NaN
# std             0.0          NaN            NaN         NaN              NaN
# min             2.0          NaN            NaN         NaN              NaN
# 25%             2.0          NaN            NaN         NaN              NaN
# 50%             2.0          NaN            NaN         NaN              NaN
# 75%             2.0          NaN            NaN         NaN              NaN
# max             2.0          NaN            NaN         NaN              NaN
#
#               overall      potential     value_eur      wage_eur  \
# count   180021.000000  180021.000000  1.778680e+05  178173.00000
# unique            NaN            NaN           NaN           NaN
# top               NaN            NaN           NaN           NaN
# freq              NaN            NaN           NaN           NaN
# mean        65.712711      70.779581  2.379142e+06   10638.01081
# std          7.018104       6.255569  6.184358e+06   21637.41400
# min         40.000000      40.000000  1.000000e+03     500.00000
# 25%         61.000000      66.000000  3.250000e+05    2000.00000
# 50%         66.000000      71.000000  7.500000e+05    4000.00000
# 75%         70.000000      75.000000  1.800000e+06   10000.00000
# max         94.000000      95.000000  1.940000e+08  575000.00000
#
#                   age         dob      height_cm      weight_kg  \
# count   180021.000000      180021  180021.000000  180021.000000
# unique            NaN        9546            NaN            NaN
# top               NaN  1992-02-29            NaN            NaN
# freq              NaN        1065            NaN            NaN
# mean        25.138689         NaN     181.287061      75.233356
# std          4.679389         NaN       6.764179       6.999181
# min         16.000000         NaN     154.000000      49.000000
# 25%         21.000000         NaN     176.000000      70.000000
# 50%         25.000000         NaN     181.000000      75.000000
# 75%         28.000000         NaN     186.000000      80.000000
# max         54.000000         NaN     208.000000     110.000000
#
#          club_team_id club_name      league_id     league_name   league_level  \
# count   178156.000000    178156  178156.000000          178156  177771.000000
# unique            NaN      1082            NaN              42            NaN
# top               NaN   Everton            NaN  Premier League            NaN
# freq              NaN       444            NaN            9371            NaN
# mean     45263.728210       NaN     221.747991             NaN       1.380878
# std      53516.528046       NaN     467.804515             NaN       0.750647
# min          1.000000       NaN       1.000000             NaN       1.000000
# 25%        450.000000       NaN      19.000000             NaN       1.000000
# 50%       1891.000000       NaN      56.000000             NaN       1.000000
# 75%     110912.000000       NaN     308.000000             NaN       2.000000
# max     131389.000000       NaN    2149.000000             NaN       5.000000
#
#        club_position  club_jersey_number club_loaned_from club_joined_date  \
# count         178156       178156.000000            10723           167433
# unique            29                 NaN              831             4417
# top              SUB                 NaN         Atalanta       2017-07-01
# freq           77123                 NaN              145             4411
# mean             NaN           20.302297              NaN              NaN
# std              NaN           17.054347              NaN              NaN
# min              NaN            1.000000              NaN              NaN
# 25%              NaN            8.000000              NaN              NaN
# 50%              NaN           17.000000              NaN              NaN
# 75%              NaN           27.000000              NaN              NaN
# max              NaN           99.000000              NaN              NaN
#
#         club_contract_valid_until_year  nationality_id nationality_name  \
# count                    178156.000000   180021.000000           180021
# unique                             NaN             NaN              188
# top                                NaN             NaN          England
# freq                               NaN             NaN            16415
# mean                       2020.816015       55.657218              NaN
# std                           2.902942       48.050844              NaN
# min                        2014.000000        1.000000              NaN
# 25%                        2019.000000       21.000000              NaN
# 50%                        2021.000000       45.000000              NaN
# 75%                        2023.000000       56.000000              NaN
# max                        2032.000000      219.000000              NaN
#
#         nation_team_id nation_position  nation_jersey_number preferred_foot  \
# count     10098.000000           10098          10098.000000         180021
# unique             NaN              29                   NaN              2
# top                NaN             SUB                   NaN          Right
# freq               NaN            5217                   NaN         137660
# mean      29845.186671             NaN             12.226580            NaN
# std       47980.430480             NaN              6.911397            NaN
# min         974.000000             NaN              1.000000            NaN
# 25%        1343.000000             NaN              6.000000            NaN
# 50%        1365.000000             NaN             12.000000            NaN
# 75%      105035.000000             NaN             18.000000            NaN
# max      111527.000000             NaN             97.000000            NaN
#
#             weak_foot    skill_moves  international_reputation      work_rate  \
# count   180021.000000  180021.000000             180021.000000         180021
# unique            NaN            NaN                       NaN              9
# top               NaN            NaN                       NaN  Medium/Medium
# freq              NaN            NaN                       NaN          98366
# mean         2.939657       2.335689                  1.105171            NaN
# std          0.664775       0.754452                  0.381699            NaN
# min          1.000000       1.000000                  1.000000            NaN
# 25%          3.000000       2.000000                  1.000000            NaN
# 50%          3.000000       2.000000                  1.000000            NaN
# 75%          3.000000       3.000000                  1.000000            NaN
# max          5.000000       5.000000                  5.000000            NaN
#
#                body_type real_face  release_clause_eur player_tags  \
# count             180021    180021        1.207220e+05       13918
# unique                10         2                 NaN         204
# top     Normal (170-185)        No                 NaN   #Strength
# freq               63022    163565                 NaN        4714
# mean                 NaN       NaN        4.878321e+06         NaN
# std                  NaN       NaN        1.271795e+07         NaN
# min                  NaN       NaN        9.000000e+03         NaN
# 25%                  NaN       NaN        6.332500e+05         NaN
# 50%                  NaN       NaN        1.400000e+06         NaN
# 75%                  NaN       NaN        3.600000e+06         NaN
# max                  NaN       NaN        3.735000e+08         NaN
#
#               player_traits           pace       shooting        passing  \
# count                 81805  159997.000000  159997.000000  159997.000000
# unique                 5208            NaN            NaN            NaN
# top     Speed Dribbler (AI)            NaN            NaN            NaN
# freq                   4442            NaN            NaN            NaN
# mean                    NaN      68.058839      52.268155      56.995731
# std                     NaN      11.063818      13.920686      10.427677
# min                     NaN      21.000000      14.000000      20.000000
# 25%                     NaN      62.000000      42.000000      50.000000
# 50%                     NaN      69.000000      54.000000      58.000000
# 75%                     NaN      76.000000      63.000000      64.000000
# max                     NaN      97.000000      94.000000      94.000000
#
#             dribbling      defending         physic  attacking_crossing  \
# count   159997.000000  159997.000000  159997.000000       180021.000000
# unique            NaN            NaN            NaN                 NaN
# top               NaN            NaN            NaN                 NaN
# freq              NaN            NaN            NaN                 NaN
# mean        62.160484      51.232742      64.824322           49.622605
# std         10.220788      16.580676       9.755666           17.985783
# min         22.000000      14.000000      27.000000            5.000000
# 25%         56.000000      36.000000      58.000000           38.000000
# 50%         63.000000      56.000000      66.000000           54.000000
# 75%         69.000000      64.000000      72.000000           63.000000
# max         96.000000      91.000000      92.000000           95.000000
#
#         attacking_finishing  attacking_heading_accuracy  \
# count         180021.000000               180021.000000
# unique                  NaN                         NaN
# top                     NaN                         NaN
# freq                    NaN                         NaN
# mean              45.687803                   52.205720
# std               19.281183                   17.146296
# min                2.000000                    4.000000
# 25%               30.000000                   44.000000
# 50%               49.000000                   55.000000
# 75%               62.000000                   64.000000
# max               96.000000                   95.000000
#
#         attacking_short_passing  attacking_volleys  skill_dribbling  \
# count             180021.000000      180021.000000    180021.000000
# unique                      NaN                NaN              NaN
# top                         NaN                NaN              NaN
# freq                        NaN                NaN              NaN
# mean                  58.434510          42.974686        55.296321
# std                   14.651313          17.449400        18.614112
# min                    7.000000           3.000000         2.000000
# 25%                   53.000000          30.000000        48.000000
# 50%                   62.000000          44.000000        61.000000
# 75%                   68.000000          56.000000        68.000000
# max                   95.000000          93.000000        97.000000
#
#           skill_curve  skill_fk_accuracy  skill_long_passing  \
# count   180021.000000      180021.000000       180021.000000
# unique            NaN                NaN                 NaN
# top               NaN                NaN                 NaN
# freq              NaN                NaN                 NaN
# mean        47.351876          43.028008           52.709312
# std         18.059794          17.196317           15.172114
# min          4.000000           3.000000            5.000000
# 25%         35.000000          31.000000           43.000000
# 50%         49.000000          42.000000           56.000000
# 75%         61.000000          56.000000           64.000000
# max         94.000000          95.000000           95.000000
#
#         skill_ball_control  movement_acceleration  movement_sprint_speed  \
# count        180021.000000          180021.000000          180021.000000
# unique                 NaN                    NaN                    NaN
# top                    NaN                    NaN                    NaN
# freq                   NaN                    NaN                    NaN
# mean             58.251404              64.695080              64.866871
# std              16.576721              14.789598              14.543439
# min               5.000000              11.000000              11.000000
# 25%              54.000000              57.000000              57.000000
# 50%              63.000000              67.000000              67.000000
# 75%              69.000000              75.000000              75.000000
# max              96.000000              97.000000              97.000000
#
#         movement_agility  movement_reactions  movement_balance  \
# count      180021.000000       180021.000000     180021.000000
# unique               NaN                 NaN               NaN
# top                  NaN                 NaN               NaN
# freq                 NaN                 NaN               NaN
# mean           63.383000           61.588059         63.951445
# std            14.725512            9.144995         14.082868
# min            11.000000           20.000000         10.000000
# 25%            55.000000           55.000000         56.000000
# 50%            66.000000           62.000000         66.000000
# 75%            74.000000           68.000000         74.000000
# max            96.000000           96.000000         97.000000
#
#         power_shot_power  power_jumping  power_stamina  power_strength  \
# count      180021.000000  180021.000000  180021.000000   180021.000000
# unique               NaN            NaN            NaN             NaN
# top                  NaN            NaN            NaN             NaN
# freq                 NaN            NaN            NaN             NaN
# mean           56.812672      65.023120      63.068586       65.128474
# std            15.290486      11.898887      15.875722       12.615282
# min             2.000000      13.000000      10.000000       12.000000
# 25%            47.000000      58.000000      56.000000       58.000000
# 50%            59.000000      66.000000      66.000000       66.000000
# 75%            68.000000      73.000000      74.000000       74.000000
# max            96.000000      97.000000      97.000000       98.000000
#
#         power_long_shots  mentality_aggression  mentality_interceptions  \
# count      180021.000000         180021.000000            180021.000000
# unique               NaN                   NaN                      NaN
# top                  NaN                   NaN                      NaN
# freq                 NaN                   NaN                      NaN
# mean           47.101505             55.714289                46.617700
# std            19.051298             17.176139                20.414351
# min             3.000000              2.000000                 3.000000
# 25%            32.000000             44.000000                26.000000
# 50%            51.000000             58.000000                52.000000
# 75%            62.000000             69.000000                64.000000
# max            94.000000             96.000000                93.000000
#
#         mentality_positioning  mentality_vision  mentality_penalties  \
# count           180021.000000     180021.000000        180021.000000
# unique                    NaN               NaN                  NaN
# top                       NaN               NaN                  NaN
# freq                      NaN               NaN                  NaN
# mean                50.047078         53.187567            48.579993
# std                 19.231630         14.193916            15.660671
# min                  2.000000          3.000000             5.000000
# 25%                 39.000000         44.000000            39.000000
# 50%                 55.000000         55.000000            50.000000
# 75%                 64.000000         64.000000            60.000000
# max                 96.000000         96.000000            96.000000
#
#         mentality_composure  defending_marking_awareness  \
# count         147133.000000                180021.000000
# unique                  NaN                          NaN
# top                     NaN                          NaN
# freq                    NaN                          NaN
# mean              57.837807                    45.851456
# std               12.305995                    20.452502
# min                3.000000                     1.000000
# 25%               50.000000                    26.000000
# 50%               59.000000                    51.000000
# 75%               66.000000                    63.000000
# max               96.000000                    94.000000
#
#         defending_standing_tackle  defending_sliding_tackle  \
# count               180021.000000             180021.000000
# unique                        NaN                       NaN
# top                           NaN                       NaN
# freq                          NaN                       NaN
# mean                    47.759511                 45.764783
# std                     21.309061                 20.899683
# min                      2.000000                  3.000000
# 25%                     27.000000                 25.000000
# 50%                     55.000000                 52.000000
# 75%                     66.000000                 64.000000
# max                     94.000000                 95.000000
#
#         goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        180021.000000         180021.000000        180021.000000
# unique                 NaN                   NaN                  NaN
# top                    NaN                   NaN                  NaN
# freq                   NaN                   NaN                  NaN
# mean             16.509979             16.260136            16.129902
# std              17.661659             16.846583            16.499513
# min               1.000000              1.000000             1.000000
# 25%               8.000000              8.000000             8.000000
# 50%              11.000000             11.000000            11.000000
# 75%              14.000000             14.000000            14.000000
# max              91.000000             92.000000            95.000000
#
#         goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# count             180021.000000         180021.000000       20024.000000
# unique                      NaN                   NaN                NaN
# top                         NaN                   NaN                NaN
# freq                        NaN                   NaN                NaN
# mean                  16.276951             16.615517          38.750300
# std                   17.009393             17.971201          10.578237
# min                    1.000000              1.000000          12.000000
# 25%                    8.000000              8.000000          30.000000
# 50%                   11.000000             11.000000          40.000000
# 75%                   14.000000             14.000000          46.000000
# max                   92.000000             94.000000          68.000000
#
#             ls      st      rs      lw      lf      cf      rf      rw  \
# count   180021  180021  180021  180021  180021  180021  180021  180021
# unique     401     401     401     340     310     310     310     340
# top       60+2    60+2    60+2      64      62      62      62      64
# freq      3510    3510    3510    7013    7055    7055    7055    7013
# mean       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# std        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# min        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 25%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 50%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 75%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# max        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#            lam     cam     ram      lm     lcm      cm     rcm      rm  \
# count   180021  180021  180021  180021  180021  180021  180021  180021
# unique     441     441     441     422     390     390     390     422
# top       62+2    62+2    62+2    62+2    60+2    60+2    60+2    62+2
# freq      3746    3746    3746    3702    3827    3827    3827    3702
# mean       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# std        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# min        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 25%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 50%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 75%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# max        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#            lwb     ldm     cdm     rdm     rwb      lb     lcb      cb  \
# count   180021  180021  180021  180021  180021  180021  180021  180021
# unique     399     429     429     429     399     393     475     475
# top       60+2    61+2    61+2    61+2    60+2    62+2    63+2    63+2
# freq      3524    3160    3160    3160    3524    3531    2650    2650
# mean       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# std        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# min        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 25%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 50%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 75%        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# max        NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#            rcb      rb      gk
# count   180021  180021  180021
# unique     475     393     297
# top       63+2    62+2    16+2
# freq      2650    3531   18568
# mean       NaN     NaN     NaN
# std        NaN     NaN     NaN
# min        NaN     NaN     NaN
# 25%        NaN     NaN     NaN
# 50%        NaN     NaN     NaN
# 75%        NaN     NaN     NaN
# max        NaN     NaN     NaN

# %% [markdown]
# Let's find out exactly how many columns we have

# %%
len(df.columns) # length of columns list
# Out:
# 109

# %% [markdown]
# # Initial Data Preperation
#
# Now we have sucessfully imported the dataset, we need to prepare it for the task at hand.

# %% [markdown]
# We will focusing on the Premier League data only so let's filter the dataset to satisfy this requirement

# %%
df = df[df['league_name'] == 'Premier League'] # filter league_name to 'Premier League'
df
# Out:
#         player_id  \
# 1          239085
# 2          192985
# 9          212831
# 10         231866
# 11         239818
# ...           ...
# 179683     225068
# 179693     222112
# 179720     201214
# 179783     213693
# 179819     222111
#
#                                                          player_url  \
# 1                              /player/239085/erling-haaland/240002
# 2                             /player/192985/kevin-de-bruyne/240002
# 9                       /player/212831/alisson-ramses-becker/240002
# 10                 /player/231866/rodrigo-hernandez-cascante/240002
# 11               /player/239818/ruben-santos-gato-alves-dias/240002
# ...                                                             ...
# 179683  https://sofifa.com/player/225068/jamie-dean-mcdonagh/150002
# 179693       https://sofifa.com/player/222112/elliot-justham/150002
# 179720        https://sofifa.com/player/201214/apti-akhyadov/150002
# 179783         https://sofifa.com/player/213693/joe-rothwell/150002
# 179819           https://sofifa.com/player/222111/andy-parry/150002
#
#         fifa_version  fifa_update update_as_of    short_name  \
# 1               24.0          2.0   2023-09-22    E. Haaland
# 2               24.0          2.0   2023-09-22  K. De Bruyne
# 9               24.0          2.0   2023-09-22       Alisson
# 10              24.0          2.0   2023-09-22         Rodri
# 11              24.0          2.0   2023-09-22   RÃºben Dias
# ...              ...          ...          ...           ...
# 179683          15.0          2.0   2014-09-18   J. McDonagh
# 179693          15.0          2.0   2014-09-18    E. Justham
# 179720          15.0          2.0   2014-09-18   A. Akhyadov
# 179783          15.0          2.0   2014-09-18   J. Rothwell
# 179819          15.0          2.0   2014-09-18      A. Parry
#
#                                 long_name player_positions  overall  \
# 1                    Erling Braut Haaland               ST       91
# 2                         Kevin De Bruyne          CM, CAM       91
# 9                  Alisson RamsÃ©s Becker               GK       89
# 10            Rodrigo HernÃ¡ndez Cascante          CDM, CM       89
# 11      RÃºben dos Santos Gato Alves Dias               CB       89
# ...                                   ...              ...      ...
# 179683                     Jamie McDonagh               RW       50
# 179693                     Elliot Justham               GK       50
# 179720                      Apti Akhyadov               CF       49
# 179783                       Joe Rothwell               CM       49
# 179819                       Andrew Parry      CDM, CB, RB       49
#
#         potential    value_eur  wage_eur  age         dob  height_cm  \
# 1              94  185000000.0  340000.0   22  2000-07-21        195
# 2              91  103000000.0  350000.0   32  1991-06-28        181
# 9              90   77500000.0  180000.0   30  1992-10-02        193
# 10             90  105500000.0  250000.0   27  1996-06-22        191
# 11             90  106500000.0  250000.0   26  1997-05-14        187
# ...           ...          ...       ...  ...         ...        ...
# 179683         55      30000.0    2000.0   18  1996-05-08        168
# 179693         54      30000.0    2000.0   24  1990-02-18        191
# 179720         61      30000.0    2000.0   20  1993-08-24        173
# 179783         55      25000.0    2000.0   19  1995-01-11        185
# 179819         53      20000.0    2000.0   22  1991-09-13        179
#
#         weight_kg  club_team_id          club_name  league_id     league_name  \
# 1              94          10.0    Manchester City       13.0  Premier League
# 2              75          10.0    Manchester City       13.0  Premier League
# 9              91           9.0          Liverpool       13.0  Premier League
# 10             82          10.0    Manchester City       13.0  Premier League
# 11             82          10.0    Manchester City       13.0  Premier League
# ...           ...           ...                ...        ...             ...
# 179683         58        1794.0   Sheffield United       60.0  Premier League
# 179693         80        1923.0         Luton Town       61.0  Premier League
# 179720         68      110109.0       Terek Grozny       67.0  Premier League
# 179783         77          11.0  Manchester United       13.0  Premier League
# 179819         73        1923.0         Luton Town       61.0  Premier League
#
#         league_level club_position  club_jersey_number club_loaned_from  \
# 1                1.0            ST                 9.0              NaN
# 2                1.0           SUB                17.0              NaN
# 9                1.0            GK                 1.0              NaN
# 10               1.0           RCM                16.0              NaN
# 11               1.0           LCB                 3.0              NaN
# ...              ...           ...                 ...              ...
# 179683           3.0           RES                27.0              NaN
# 179693           4.0           SUB                16.0              NaN
# 179720           1.0           SUB                93.0              NaN
# 179783           1.0           RES                46.0              NaN
# 179819           4.0           RES                14.0              NaN
#
#        club_joined_date  club_contract_valid_until_year  nationality_id  \
# 1            2022-07-01                          2027.0              36
# 2            2015-08-30                          2025.0               7
# 9            2018-07-19                          2027.0              54
# 10           2019-07-04                          2027.0              45
# 11           2020-09-29                          2027.0              38
# ...                 ...                             ...             ...
# 179683       2014-08-18                          2015.0              25
# 179693       2013-05-13                          2015.0              14
# 179720       2010-03-11                          2019.0              40
# 179783       2014-07-31                          2015.0              14
# 179819       2013-07-01                          2015.0              14
#
#            nationality_name  nation_team_id nation_position  \
# 1                    Norway          1352.0              ST
# 2                   Belgium          1325.0             CAM
# 9                    Brazil             NaN             NaN
# 10                    Spain          1362.0             RCM
# 11                 Portugal          1354.0             RCB
# ...                     ...             ...             ...
# 179683  Republic of Ireland             NaN             NaN
# 179693              England             NaN             NaN
# 179720               Russia             NaN             NaN
# 179783              England             NaN             NaN
# 179819              England             NaN             NaN
#
#         nation_jersey_number preferred_foot  weak_foot  skill_moves  \
# 1                        9.0           Left          3            3
# 2                        7.0          Right          5            4
# 9                        NaN          Right          3            1
# 10                      16.0          Right          4            3
# 11                       4.0          Right          4            2
# ...                      ...            ...        ...          ...
# 179683                   NaN          Right          3            2
# 179693                   NaN           Left          3            1
# 179720                   NaN          Right          3            2
# 179783                   NaN          Right          2            2
# 179819                   NaN          Right          3            2
#
#         international_reputation      work_rate         body_type real_face  \
# 1                              5    High/Medium            Unique       Yes
# 2                              5    High/Medium            Unique       Yes
# 9                              5  Medium/Medium            Unique       Yes
# 10                             4    Medium/High     Normal (185+)       Yes
# 11                             4    Medium/High     Normal (185+)       Yes
# ...                          ...            ...               ...       ...
# 179683                         1  Medium/Medium       Lean (170-)        No
# 179693                         1  Medium/Medium     Stocky (185+)        No
# 179720                         1  Medium/Medium  Stocky (170-185)        No
# 179783                         1  Medium/Medium       Lean (185+)        No
# 179819                         1    Medium/High  Normal (170-185)        No
#
#         release_clause_eur  \
# 1              356100000.0
# 2              190600000.0
# 9              149200000.0
# 10             203100000.0
# 11             205000000.0
# ...                    ...
# 179683                 NaN
# 179693                 NaN
# 179720                 NaN
# 179783                 NaN
# 179819                 NaN
#
#                                                                                 player_tags  \
# 1       #Aerial threat, #Distance shooter, #Strength, #Clinical finisher, #Complete forward
# 2                  #Dribbler, #Playmaker, #Distance shooter, #Crosser, #Complete midfielder
# 9                                                                                       NaN
# 10                                                                                      NaN
# 11                                     #Tackling, #Tactician, #Strength, #Complete defender
# ...                                                                                     ...
# 179683                                                                                  NaN
# 179693                                                                                  NaN
# 179720                                                                                  NaN
# 179783                                                                                  NaN
# 179819                                                                                  NaN
#
#                                                                           player_traits  \
# 1                                                 Acrobatic +, Power Header, Quick Step
# 2       Pinged Pass +, Dead Ball, Incisive Pass, Long Ball Pass, Whipped Cross, Trivela
# 9                                                                             Far Throw
# 10                                                Power Shot +, Long Ball Pass, Bruiser
# 11                                               Bruiser +, Power Header, Block, Aerial
# ...                                                                                 ...
# 179683                                                                              NaN
# 179693                                                                              NaN
# 179720                                                                              NaN
# 179783                                                                              NaN
# 179819                                                                              NaN
#
#         pace  shooting  passing  dribbling  defending  physic  \
# 1       89.0      93.0     66.0       80.0       45.0    88.0
# 2       72.0      88.0     94.0       87.0       65.0    78.0
# 9        NaN       NaN      NaN        NaN        NaN     NaN
# 10      58.0      73.0     80.0       80.0       85.0    84.0
# 11      62.0      39.0     66.0       69.0       89.0    87.0
# ...      ...       ...      ...        ...        ...     ...
# 179683  65.0      50.0     41.0       53.0       25.0    32.0
# 179693   NaN       NaN      NaN        NaN        NaN     NaN
# 179720  66.0      51.0     34.0       52.0       29.0    46.0
# 179783  65.0      41.0     55.0       54.0       37.0    42.0
# 179819  58.0      40.0     46.0       42.0       47.0    60.0
#
#         attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 1                       47                   96                          83
# 2                       95                   85                          55
# 9                       17                   13                          29
# 10                      63                   64                          81
# 11                      54                   29                          87
# ...                    ...                  ...                         ...
# 179683                  52                   50                          35
# 179693                  25                   25                          25
# 179720                  30                   56                          42
# 179783                  44                   42                          41
# 179819                  38                   39                          47
#
#         attacking_short_passing  attacking_volleys  skill_dribbling  \
# 1                            77                 90               79
# 2                            94                 83               86
# 9                            60                 20               27
# 10                           89                 59               79
# 11                           83                 32               64
# ...                         ...                ...              ...
# 179683                       37                 37               52
# 179693                       25                 25               25
# 179720                       26                 51               50
# 179783                       63                 38               53
# 179819                       48                 47               38
#
#         skill_curve  skill_fk_accuracy  skill_long_passing  \
# 1                77                 62                  53
# 2                92                 83                  94
# 9                19                 18                  58
# 10               65                 61                  90
# 11               46                 48                  76
# ...             ...                ...                 ...
# 179683           38                 39                  30
# 179693           25                 25                  24
# 179720           46                 42                  38
# 179783           41                 42                  60
# 179819           33                 31                  53
#
#         skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 1                       82                     82                     94
# 2                       92                     72                     72
# 9                       42                     60                     49
# 10                      88                     54                     62
# 11                      75                     54                     69
# ...                    ...                    ...                    ...
# 179683                  49                     68                     63
# 179693                  21                     45                     47
# 179720                  42                     65                     67
# 179783                  50                     60                     69
# 179819                  39                     58                     58
#
#         movement_agility  movement_reactions  movement_balance  \
# 1                     76                  94                72
# 2                     74                  92                78
# 9                     40                  87                37
# 10                    65                  89                64
# 11                    60                  89                56
# ...                  ...                 ...               ...
# 179683                65                  38                82
# 179693                37                  46                59
# 179720                74                  50                80
# 179783                64                  53                64
# 179819                63                  48                57
#
#         power_shot_power  power_jumping  power_stamina  power_strength  \
# 1                     94             93             76              93
# 2                     92             72             88              74
# 9                     64             82             32              78
# 10                    91             80             89              83
# 11                    74             84             78              90
# ...                  ...            ...            ...             ...
# 179683                65             47             32              31
# 179693                21             55             33              51
# 179720                50             72             32              43
# 179783                51             54             40              42
# 179819                40             73             62              64
#
#         power_long_shots  mentality_aggression  mentality_interceptions  \
# 1                     86                    87                       43
# 2                     92                    75                       66
# 9                     14                    27                       11
# 10                    82                    83                       84
# 11                    26                    93                       86
# ...                  ...                   ...                      ...
# 179683                38                    32                       21
# 179693                25                    25                       23
# 179720                44                    64                       41
# 179783                30                    42                       23
# 179819                40                    45                       47
#
#         mentality_positioning  mentality_vision  mentality_penalties  \
# 1                          96                74                   84
# 2                          88                95                   83
# 9                          13                66                   23
# 10                         75                82                   62
# 11                         39                51                   45
# ...                       ...               ...                  ...
# 179683                     44                45                   48
# 179693                     25                25                   22
# 179720                     57                42                   40
# 179783                     41                54                   44
# 179819                     45                51                   30
#
#         mentality_composure  defending_marking_awareness  \
# 1                      87.0                           38
# 2                      88.0                           66
# 9                      66.0                           15
# 10                     85.0                           88
# 11                     81.0                           91
# ...                     ...                          ...
# 179683                  NaN                           21
# 179693                  NaN                           25
# 179720                  NaN                           21
# 179783                  NaN                           38
# 179819                  NaN                           42
#
#         defending_standing_tackle  defending_sliding_tackle  \
# 1                              47                        29
# 2                              70                        53
# 9                              19                        16
# 10                             87                        78
# 11                             91                        87
# ...                           ...                       ...
# 179683                         27                        25
# 179693                         21                        21
# 179720                         25                        25
# 179783                         41                        42
# 179819                         52                        51
#
#         goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 1                        7                    14                   13
# 2                       15                    13                    5
# 9                       86                    85                   85
# 10                      10                    10                    7
# 11                       7                     8                   13
# ...                    ...                   ...                  ...
# 179683                   9                     7                   12
# 179693                  53                    43                   48
# 179720                   8                    10                    7
# 179783                  13                     7                   12
# 179819                  13                     7                    7
#
#         goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed  \
# 1                            11                     7                NaN
# 2                            10                    13                NaN
# 9                            90                    89               56.0
# 10                           14                     8                NaN
# 11                            7                    12                NaN
# ...                         ...                   ...                ...
# 179683                        8                     7                NaN
# 179693                       49                    54               46.0
# 179720                       12                    12                NaN
# 179783                       14                     8                NaN
# 179819                       14                     6                NaN
#
#           ls    st    rs  lw  lf  cf  rf  rw   lam   cam   ram    lm   lcm  \
# 1       90+3  90+3  90+3  82  86  86  86  82  82+3  82+3  82+3  79+3  74+3
# 2       83+3  83+3  83+3  87  88  88  88  87  89+2  89+2  89+2  88+3  90+1
# 9       39+3  39+3  39+3  39  42  42  42  39  45+3  45+3  45+3  42+3  46+3
# 10      77+3  77+3  77+3  76  79  79  79  76  80+3  80+3  80+3  78+3  85+3
# 11      61+3  61+3  61+3  60  61  61  61  60  62+3  62+3  62+3  64+3  70+3
# ...      ...   ...   ...  ..  ..  ..  ..  ..   ...   ...   ...   ...   ...
# 179683    48    48    48  50  48  48  48  50    47    47    47    47    38
# 179693    29    29    29  29  28  28  28  29    27    27    27    29    26
# 179720    52    52    52  47  49  49  49  47    46    46    46    44    40
# 179783    46    46    46  52  48  48  48  52    52    52    52    53    49
# 179819    44    44    44  45  44  44  44  45    46    46    46    47    48
#
#           cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb  \
# 1       74+3  74+3  79+3  62+3  63+3  63+3  63+3  62+3  60+3  62+3  62+3
# 2       90+1  90+1  88+3  79+3  80+3  80+3  80+3  79+3  75+3  70+3  70+3
# 9       46+3  46+3  42+3  34+3  39+3  39+3  39+3  34+3  33+3  33+3  33+3
# 10      85+3  85+3  78+3  80+3  87+3  87+3  87+3  80+3  80+3  84+3  84+3
# 11      70+3  70+3  64+3  78+3  83+3  83+3  83+3  78+3  80+3  88+2  88+2
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 179683    38    38    47    37    32    32    32    37    33    30    30
# 179693    26    26    29    27    28    28    28    27    27    28    28
# 179720    40    40    44    36    37    37    37    36    36    36    36
# 179783    49    49    53    46    46    46    46    46    43    42    42
# 179819    48    48    47    47    49    49    49    47    48    50    50
#
#          rcb    rb    gk
# 1       62+3  60+3  19+3
# 2       70+3  75+3  21+3
# 9       33+3  33+3  87+3
# 10      84+3  80+3  19+3
# 11      88+2  80+3  18+3
# ...      ...   ...   ...
# 179683    30    33    10
# 179693    28    27    50
# 179720    36    36    13
# 179783    42    43    13
# 179819    50    48    12
#
# [9371 rows x 109 columns]

# %% [markdown]
# The current dataset has too many features with a large portion being irrelevant to the task at hand. We will drop the columns that aren't relevant using the .drop() function.

# %%
df.drop([
    'player_id',
    'wage_eur',
    'player_url',
    'update_as_of',
    'short_name',
    'long_name',
    'dob',
    'club_name',
    'league_name',
    'club_position',
    'club_loaned_from',
    'club_joined_date',
    'nationality_id',
    'nationality_name',
    'nation_position',
    'body_type',
    'real_face',
    'player_tags',
    'player_traits',
    'fifa_update',
    'league_level',
    'club_team_id',
    'league_id',
    'club_jersey_number',
    'club_contract_valid_until_year',
    'nation_team_id',
    'nation_jersey_number',
    'release_clause_eur',
    'height_cm',
    'weight_kg',
    'ls',
    'st',
    'rs',
    'lw',
    'lf',
    'cf',
    'rf',
    'rw',
    'lam',
    'cam',
    'ram',
    'lm',
    'lcm',
    'cm',
    'rcm',
    'rm',
    'lwb',
    'ldm',
    'cdm',
    'rdm',
    'rwb',
    'lb',
    'lcb',
    'cb',
    'rcb',
    'rb',
    'gk',
    'work_rate',
    'attacking_crossing',
    'attacking_finishing',
    'attacking_heading_accuracy',
    'attacking_short_passing',
    'attacking_volleys',
    'skill_dribbling',
    'skill_curve',
    'skill_fk_accuracy',
    'skill_long_passing',
    'skill_ball_control',
    'movement_acceleration',
    'movement_sprint_speed',
    'movement_agility',
    'movement_reactions',
    'movement_balance',
    'power_shot_power',
    'power_jumping',
    'power_stamina',
    'power_strength',
    'power_long_shots',
    'mentality_aggression',
    'mentality_interceptions',
    'mentality_positioning',
    'mentality_vision',
    'mentality_penalties',
    'mentality_composure',
    'defending_marking_awareness',
    'defending_standing_tackle',
    'defending_sliding_tackle',
    'goalkeeping_diving',
    'goalkeeping_handling',
    'goalkeeping_kicking',
    'goalkeeping_positioning',
    'goalkeeping_reflexes',
    'goalkeeping_speed'
], axis=1, inplace=True)
df
# Out:
# C:\Users\Ishina\AppData\Local\Temp\ipykernel_47832\3865313029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([
#         fifa_version player_positions  overall  potential    value_eur  age  \
# 1               24.0               ST       91         94  185000000.0   22
# 2               24.0          CM, CAM       91         91  103000000.0   32
# 9               24.0               GK       89         90   77500000.0   30
# 10              24.0          CDM, CM       89         90  105500000.0   27
# 11              24.0               CB       89         90  106500000.0   26
# ...              ...              ...      ...        ...          ...  ...
# 179683          15.0               RW       50         55      30000.0   18
# 179693          15.0               GK       50         54      30000.0   24
# 179720          15.0               CF       49         61      30000.0   20
# 179783          15.0               CM       49         55      25000.0   19
# 179819          15.0      CDM, CB, RB       49         53      20000.0   22
#
#        preferred_foot  weak_foot  skill_moves  international_reputation  pace  \
# 1                Left          3            3                         5  89.0
# 2               Right          5            4                         5  72.0
# 9               Right          3            1                         5   NaN
# 10              Right          4            3                         4  58.0
# 11              Right          4            2                         4  62.0
# ...               ...        ...          ...                       ...   ...
# 179683          Right          3            2                         1  65.0
# 179693           Left          3            1                         1   NaN
# 179720          Right          3            2                         1  66.0
# 179783          Right          2            2                         1  65.0
# 179819          Right          3            2                         1  58.0
#
#         shooting  passing  dribbling  defending  physic
# 1           93.0     66.0       80.0       45.0    88.0
# 2           88.0     94.0       87.0       65.0    78.0
# 9            NaN      NaN        NaN        NaN     NaN
# 10          73.0     80.0       80.0       85.0    84.0
# 11          39.0     66.0       69.0       89.0    87.0
# ...          ...      ...        ...        ...     ...
# 179683      50.0     41.0       53.0       25.0    32.0
# 179693       NaN      NaN        NaN        NaN     NaN
# 179720      51.0     34.0       52.0       29.0    46.0
# 179783      41.0     55.0       54.0       37.0    42.0
# 179819      40.0     46.0       42.0       47.0    60.0
#
# [9371 rows x 16 columns]

# %% [markdown]
# Need to extract main player position from player_positions column

# %%
#----------------------------------
# player_positions -> main_position
#----------------------------------

# list of all outfield positons can be found at https://www.fifplay.com/encyclopedia/position/
forward_positions = [
    'ST', 
    'CF',
    'RF',
    'LF',
    'RW',
    'LW',
]

midfielder_positions = [
    'CM',
    'CDM',
    'CAM',
    'RM',
    'LM',
]

defender_positions = [
    'CB',
    'RB',
    'LB',
    'RWB',
    'LWB',
]

def calc_main_position(positions: str):

    primary_position = positions.split(',')[0] # using first position mentioned as primary position

    if primary_position in forward_positions:
        return 'FW'
    elif primary_position in midfielder_positions:
        return 'MD'
    elif primary_position in defender_positions:
        return 'DF'
    elif primary_position == 'GK':
        return 'GK'
    else:
        return None # no valid position found

# Create new column with function applied to each value
df['main_position'] = df['player_positions'].apply(lambda pos: calc_main_position(pos))
# Show old columns against new column
print(df[['player_positions', 'main_position']])
# Check for nulls
print('\nNulls: ', df['main_position'].isnull().sum())
# Drop old column
df.drop(['player_positions'] ,axis=1,inplace=True)
# Out:
#        player_positions main_position
# 1                    ST            FW
# 2               CM, CAM            MD
# 9                    GK            GK
# 10              CDM, CM            MD
# 11                   CB            DF
# ...                 ...           ...
# 179683               RW            FW
# 179693               GK            GK
# 179720               CF            FW
# 179783               CM            MD
# 179819      CDM, CB, RB            MD
#
# [9371 rows x 2 columns]
#
# Nulls:  0
# C:\Users\Ishina\AppData\Local\Temp\ipykernel_47832\3918784086.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['main_position'] = df['player_positions'].apply(lambda pos: calc_main_position(pos))
# C:\Users\Ishina\AppData\Local\Temp\ipykernel_47832\3918784086.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['player_positions'] ,axis=1,inplace=True)

# %% [markdown]
# Filter data for non-goalkeeper players only

# %%
df = df[df['main_position'] != 'GK'] # filter out goalkeepers

# %%
df
# Out:
#         fifa_version  overall  potential    value_eur  age preferred_foot  \
# 1               24.0       91         94  185000000.0   22           Left
# 2               24.0       91         91  103000000.0   32          Right
# 10              24.0       89         90  105500000.0   27          Right
# 11              24.0       89         90  106500000.0   26          Right
# 14              24.0       89         89   72000000.0   31          Right
# ...              ...      ...        ...          ...  ...            ...
# 179666          15.0       50         55      30000.0   26          Right
# 179683          15.0       50         55      30000.0   18          Right
# 179720          15.0       49         61      30000.0   20          Right
# 179783          15.0       49         55      25000.0   19          Right
# 179819          15.0       49         53      20000.0   22          Right
#
#         weak_foot  skill_moves  international_reputation  pace  shooting  \
# 1               3            3                         5  89.0      93.0
# 2               5            4                         5  72.0      88.0
# 10              4            3                         4  58.0      73.0
# 11              4            2                         4  62.0      39.0
# 14              3            2                         4  63.0      75.0
# ...           ...          ...                       ...   ...       ...
# 179666          3            2                         1  60.0      33.0
# 179683          3            2                         1  65.0      50.0
# 179720          3            2                         1  66.0      51.0
# 179783          2            2                         1  65.0      41.0
# 179819          3            2                         1  58.0      40.0
#
#         passing  dribbling  defending  physic main_position
# 1          66.0       80.0       45.0    88.0            FW
# 2          94.0       87.0       65.0    78.0            MD
# 10         80.0       80.0       85.0    84.0            MD
# 11         66.0       69.0       89.0    87.0            DF
# 14         79.0       73.0       89.0    88.0            MD
# ...         ...        ...        ...     ...           ...
# 179666     39.0       45.0       50.0    63.0            MD
# 179683     41.0       53.0       25.0    32.0            FW
# 179720     34.0       52.0       29.0    46.0            FW
# 179783     55.0       54.0       37.0    42.0            MD
# 179819     46.0       42.0       47.0    60.0            MD
#
# [8347 rows x 16 columns]

# %% [markdown]
# Check for nulls

# %%
for col in df.columns:
    n_nulls = df[col].isnull().sum() # get count of column null values
    print(f"{col} - {n_nulls} nulls")
# Out:
# fifa_version - 0 nulls
# overall - 0 nulls
# potential - 0 nulls
# value_eur - 12 nulls
# age - 0 nulls
# preferred_foot - 0 nulls
# weak_foot - 0 nulls
# skill_moves - 0 nulls
# international_reputation - 0 nulls
# pace - 0 nulls
# shooting - 0 nulls
# passing - 0 nulls
# dribbling - 0 nulls
# defending - 0 nulls
# physic - 0 nulls
# main_position - 0 nulls

# %%
# Create copy of dataframe for reference
df_initial_prep = deepcopy(df)

# %% [markdown]
# # Splitting the dataset

# %% [markdown]
# Drop records with null values

# %%
df.dropna(subset=['value_eur'], inplace=True)
df['value_eur'].isnull().sum()
# Out:
# C:\Users\Ishina\AppData\Local\Temp\ipykernel_47832\4209686229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['value_eur'], inplace=True)
# 0

# %%
# import train_test_split function from sklearn
# Doc: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
from sklearn.model_selection import train_test_split

# Set target dataset to value_eur column
y = df['value_eur']
# Set features dataset to dataset minus value_eur column using .drop() function
X = df.drop(['value_eur'], axis=1)

# Split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.2, random_state=random_state
)

# Test if split was as expected by calculating percentage of each set
# This should give us a total split of 80%-10%-10% (train, valid, test)
train_percent = X_train.shape[0] / X.shape[0] * 100
test_percent = X_test.shape[0] / X.shape[0]  * 100
total_percent = train_percent+test_percent

print(f'Train: {train_percent}%\
      \nTest: {test_percent}%\
      \n------------------------\
      \nTotal: {total_percent}%')
# Out:
# Train: 80.0%
# Test: 20.0%
# ------------------------
# Total: 100.0%

# %% [markdown]
# # EDA

# %%
# Install library for plots and visualisations
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# #### Univariate

# %%
sns.displot(df['value_eur'],  kind='kde')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df[df['value_eur'] > 100000000]['value_eur'], binwidth=10000000)
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['age'], binwidth=1) # binwidth = width of each bar
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df, x='age', orient='h') # horizontal orientation
# Out:
# <Axes: xlabel='age'>

# %%
#sns.displot(df['overall'], binwidth=5)
#sns.boxplot(df['overall'], orient='h')

# %%
#sns.displot(df['potential'], binwidth=5)
#sns.boxplot(df['potential'], orient='h')

# %%
sns.catplot(df, x='fifa_version', kind='count')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['preferred_foot'])
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['preferred_foot'])
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(df, x='skill_moves', kind='count')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(df, x='weak_foot', kind='count')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(df, x='international_reputation', kind='count')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
n_records = df.shape[0] # number of records in our dataframe

#loop 5 times (1 for each rating from 1-5)
for i in range(5):
    rating = i+1 # index starts from 0 so add 1 to get rating
    
    # get number of records with this rating
    count = df[df['international_reputation']==rating].shape[0]
    percent = count / n_records * 100
    
    print(f"Intl rep rating {rating}: {percent}%")
# Out:
# Intl rep rating 1: 74.39712057588483%
# Intl rep rating 2: 17.000599880023994%
# Intl rep rating 3: 7.22255548890222%
# Intl rep rating 4: 1.2837432513497302%
# Intl rep rating 5: 0.09598080383923216%

# %%
sns.displot(df['pace'], binwidth=5, kde=True)
#sns.boxplot(df, x='pace')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df, x='shooting', binwidth=5, kde=True)
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['dribbling'], binwidth=5, kde=True)
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['passing'], binwidth=5, kde=True)
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['physic'], binwidth=5, kde=True)
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(df, x='main_position', kind='count')
# Out:
# c:\Users\Ishina\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Bivariate

# %%
## Pair Plot
"""
sns.pairplot(
    df, 
    vars=[    # 2d grid of these columns
        'value_eur',
        'age',
        'overall',
        'international_reputation',
        'skill_moves',
        'shooting',
        'pace',
        'main_position'
    ], 
)
"""
# Out:
# "\nsns.pairplot(\n    df, \n    vars=[    # 2d grid of these columns\n        'value_eur',\n        'age',\n        'overall',\n        'international_reputation',\n        'skill_moves',\n        'shooting',\n        'pace',\n        'main_position'\n    ], \n)\n"

# %%
sns.barplot(df, x='fifa_version', y='value_eur')
# Out:
# <Axes: xlabel='fifa_version', ylabel='value_eur'>

# %%
sns.lineplot(df, x='age', y='value_eur')
# Out:
# <Axes: xlabel='age', ylabel='value_eur'>

# %%
sns.lineplot(df, x='overall', y='value_eur')
# Out:
# <Axes: xlabel='overall', ylabel='value_eur'>

# %%
sns.lineplot(df, x='potential', y='value_eur')
# Out:
# <Axes: xlabel='potential', ylabel='value_eur'>

# %%
sns.barplot(df, x='main_position', y='value_eur')
# Out:
# <Axes: xlabel='main_position', ylabel='value_eur'>

# %%
sns.barplot(df, x='international_reputation', y='value_eur')
# Out:
# <Axes: xlabel='international_reputation', ylabel='value_eur'>

# %%
sns.barplot(df, x='preferred_foot', y='value_eur')
# Out:
# <Axes: xlabel='preferred_foot', ylabel='value_eur'>

# %%
sns.lineplot(df, x='weak_foot', y='value_eur')
# Out:
# <Axes: xlabel='weak_foot', ylabel='value_eur'>

# %%
sns.lineplot(df, x='shooting', y='value_eur')
# Out:
# <Axes: xlabel='shooting', ylabel='value_eur'>

# %%
sns.lineplot(df, x='dribbling', y='value_eur')
# Out:
# <Axes: xlabel='dribbling', ylabel='value_eur'>

# %%
sns.lineplot(df, x='passing', y='value_eur')
# Out:
# <Axes: xlabel='passing', ylabel='value_eur'>

# %%
sns.lineplot(df, x='physic', y='value_eur')
# Out:
# <Axes: xlabel='physic', ylabel='value_eur'>

# %%
sns.barplot(df, x='fifa_version', y='overall')
# Out:
# <Axes: xlabel='fifa_version', ylabel='overall'>

# %%
df.select_dtypes(exclude=[object]).corrwith(df["value_eur"])
# Out:
# fifa_version                0.256335
# overall                     0.658697
# potential                   0.621591
# value_eur                   1.000000
# age                         0.124445
# weak_foot                   0.151797
# skill_moves                 0.372602
# international_reputation    0.648392
# pace                        0.228705
# shooting                    0.378367
# passing                     0.500114
# dribbling                   0.479109
# defending                   0.145152
# physic                      0.310976
# dtype: float64

# %% [markdown]
# # Data cleansing / pre-processing

# %% [markdown]
# ### Missing data

# %% [markdown]
# Check each dataset for null values

# %%
# Checking null count for train features
print("X train", "\n============")
for col in X_train.columns: # loop through each feature
    n_nulls = X_train[col].isnull().sum() # get count of null values for feature
    print(f"{col} - {n_nulls} nulls")

# Checking null count for train target
print("\ny train", "\n============")
n_nulls = y_train.isnull().sum() # get count of null values
print(f"{n_nulls} nulls")

# Checking null count for test features
print("\nX test", "\n============")
for col in X_train.columns: # loop through each feature
    n_nulls = X_train[col].isnull().sum() # get count of null values for feature
    print(f"{col} - {n_nulls} nulls")

# Checking null count for test target
print("\ny test", "\n============")
n_nulls = y_test.isnull().sum() # get count of null values
print(f"{n_nulls} nulls")
# Out:
# X train
# ============
# fifa_version - 0 nulls
# overall - 0 nulls
# potential - 0 nulls
# age - 0 nulls
# preferred_foot - 0 nulls
# weak_foot - 0 nulls
# skill_moves - 0 nulls
# international_reputation - 0 nulls
# pace - 0 nulls
# shooting - 0 nulls
# passing - 0 nulls
# dribbling - 0 nulls
# defending - 0 nulls
# physic - 0 nulls
# main_position - 0 nulls
#
# y train
# ============
# 0 nulls
#
# X test
# ============
# fifa_version - 0 nulls
# overall - 0 nulls
# potential - 0 nulls
# age - 0 nulls
# preferred_foot - 0 nulls
# weak_foot - 0 nulls
# skill_moves - 0 nulls
# international_reputation - 0 nulls
# pace - 0 nulls
# shooting - 0 nulls
# passing - 0 nulls
# dribbling - 0 nulls
# defending - 0 nulls
# physic - 0 nulls
# main_position - 0 nulls
#
# y test
# ============
# 0 nulls

# %% [markdown]
# ### Data encoding / scaling

# %% [markdown]
# Dummy encoding function to transform category data to numerical data

# %%
def apply_dummy_encoding(df: pd.DataFrame, columns: list) -> None:
    """Create dummies for column(s) and drop old"""
    
    df = deepcopy(df)
    # create dummies
    df = pd.concat([df, pd.get_dummies(df, columns=columns, drop_first=True)], axis=1)
    
    # drop old columns
    df = df.drop(columns, axis=1)
    return df

# %% [markdown]
# Function to combine both preprocesing

# %%
def apply_preprocessing(df: pd.DataFrame, scaler=None) -> pd.DataFrame:
    """Apply preprocessing (encoding & scaling if needed)"""
    df = apply_dummy_encoding(df, columns=['main_position', 'preferred_foot'])

    # If scaler object is given then apply scaling
    if scaler:
        df = scaler.fit_transform(df)

    return df

# %% [markdown]
# Apply preprocessing to training and testing sets seperately to prevent data leakage

# %%
# Apply processing to each feature dataset

X_train = apply_preprocessing(X_train)
X_test = apply_preprocessing(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1588], line 3
#       1 # Apply processing to each feature dataset
# ----> 3 X_train = apply_preprocessing(X_train)
#       4 X_test = apply_preprocessing(X_test)
#
# Cell In[1569], line 3, in apply_preprocessing(df, scaler)
#       1 def apply_preprocessing(df: pd.DataFrame, scaler=None) -> pd.DataFrame:
#       2     """Apply preprocessing (encoding & scaling if needed)"""
# ----> 3     df = apply_dummy_encoding(df, columns=['main_position', 'preferred_foot'])
#       5     # If scaler object is given then apply scaling
#       6     if scaler:
#
# Cell In[1568], line 6, in apply_dummy_encoding(df, columns)
#       4 df = deepcopy(df)
#       5 # create dummies
# ----> 6 df = pd.concat([df, pd.get_dummies(df, columns=columns, drop_first=True)], axis=1)
#       8 # drop old columns
#       9 df = df.drop(columns, axis=1)
#
# File c:\Users\Ishina\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:158, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     156     raise TypeError("Input must be a list-like for parameter `columns`")
#     157 else:
# --> 158     data_to_encode = data[columns]
#     160 # validate prefixes and separator to avoid silently dropping cols
#     161 def check_len(item, name):
#
# File c:\Users\Ishina\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Ishina\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Ishina\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['main_position', 'preferred_foot'], dtype='object')] are in the [columns]"

# %% [markdown]
# # Model development

# %% [markdown]
# Inital model development

# %%
# Import random forest regressor
from sklearn.ensemble import RandomForestRegressor
# import evaluation metrics
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score
from math import sqrt

# Create random forest regressor model
rfr = RandomForestRegressor()

# Train model with train dataset
rfr.fit(X_train, y_train)

# Use the best model to make predictions
y_prediction = rfr.predict(X_test)

# Adjusted r2 function
def adjusted_r2_score(y_true, y_pred, n_features):
    r2 = r2_score(y_true, y_pred)
    n = len(y_true)
    
    adjusted_r2 = 1 - ((1 - r2) * (n - 1) / (n - n_features - 1))
    
    return adjusted_r2

# Evaluate the performance of the best model on test dataset
r2 = r2_score(y_test, y_prediction)
adj_r2 = adjusted_r2_score(y_test, y_prediction, X_train.shape[1])
mae = mean_absolute_error(y_test, y_prediction)
mse = mean_squared_error(y_test, y_prediction)
rmse = sqrt(mse)


print(f"Adjusted R²: {adj_r2}")
print(f"R²: {r2}")
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")

# %% [markdown]
# Creating model with best hyperparameters using automated hyperparameter tuning whilst cross-validating with K-Folds 3

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, r2_score
from math import sqrt


# Define the hyperparameter grid for tuning
param_distributions = {
    'n_estimators': [10, 25, 50, 75, 100],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create a dictionary of the scorers to use 
scorers = {
    'adj_r2_score': make_scorer(lambda y_true, y_pred, n_features: adjusted_r2_score(y_true, y_pred, X_train.shape[0])),
    'r2_score': make_scorer(r2_score),
    'mae': make_scorer(mean_absolute_error, greater_is_better=False),
    'mse': make_scorer(mean_squared_error, squared=True, greater_is_better=False),
    'rmse': make_scorer(lambda y_true, y_pred: sqrt(mean_squared_error(y_true, y_pred)), greater_is_better=False)
}

# Create the RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=RandomForestRegressor(), 
    param_distributions=param_distributions, 
    scoring=scorers, 
    refit='rmse', # scoring technique to use to find 'best' model
    cv=3, # number of K-Folds for cross validation
    n_iter=10, # number of iterations
    verbose=1, # less output messages
    n_jobs=-1, # use all processors for faster result
    random_state=random_state
)

# Fit the RandomSearch object to the data
random_search.fit(X_train, y_train)

# Get the best model from the grid search
best_rfr = random_search.best_estimator_
# Show hyperparameters of best model
random_search.best_params_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# c:\Users\Ishina\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# {'n_estimators': 50,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_depth': 30}

# %% [markdown]
# Evaluation on test dataset

# %%
# Use the best model to make predictions
y_prediction = best_rfr.predict(X_test)

# Evaluate the performance of the best model on test dataset
r2 = r2_score(y_test, y_prediction)
adj_r2 = adjusted_r2_score(y_test, y_prediction, X_train.shape[1])
mae = mean_absolute_error(y_test, y_prediction)
mse = mean_squared_error(y_test, y_prediction)
rmse = sqrt(mse)


print(f"Adjusted R²: {adj_r2}")
print(f"R²: {r2}")
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
# Out:
# Adjusted R²: 0.9759050863700549
# R²: 0.9763245056349219
# MAE: 446655.84883023397
# MSE: 3789147569844.0312
# RMSE: 1946573.289101654

# %% [markdown]
# Visualise model prediction performance

# %%
sns.scatterplot(x=y_test, y=y_prediction)
# Out:
# <Axes: xlabel='value_eur'>

# %%
sns.regplot(x=y_test, y=y_prediction, line_kws=dict(color="r"))
# Out:
# <Axes: xlabel='value_eur'>

# %% [markdown]
# Plot feature importance

# %%
# Get feature importances from the trained model
feature_importances = best_rfr.feature_importances_

# Get feature names from your dataset (assuming you have X_train available)
feature_names = X_train.columns

# Create a DataFrame for easier plotting
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances using Seaborn and Matplotlib
sns.barplot(x='Importance', y='Feature', data=importance_df)
# Out:
# <Axes: xlabel='Importance', ylabel='Feature'>

# %% [markdown]
# # Model improvement

# %%
# Obtain fresh copy of df after inital prep
df = deepcopy(df_initial_prep)

# Experiment with dropping features
#df = df[df['fifa_version'] == 24]
#df.drop(columns=['overall', 'potential','fifa_version'], axis=1, inplace=True)

# %%
# Drop records with null values
df.dropna(subset=['value_eur'], inplace=True)
df['value_eur'].isnull().sum()

# Split dataset
y = df['value_eur']
X = df.drop(['value_eur'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.2, random_state=random_state
)

# %%
# apply preprocessing
X_train = apply_preprocessing(X_train)
X_test = apply_preprocessing(X_test)

# %%
# Note:
# Evaluation scorers have already been defined
# Hyperprameters have already been defined

# Create the RandomizedSearchCV object
random_search = RandomizedSearchCV(
    estimator=RandomForestRegressor(), 
    param_distributions=param_distributions, 
    scoring=scorers, 
    refit='rmse', # scoring technique to use to find 'best' model
    cv=3, # number of K-Folds for cross validation
    n_iter=10, # number of iterations
    verbose=1, # less output messages
    n_jobs=-1, # use all processors for faster result
    random_state=random_state
)

# Fit the RandomSearch object to the data
random_search.fit(X_train, y_train)

# Get the best model from the grid search
best_rfr = random_search.best_estimator_
# Show hyperparameters of best model
random_search.best_params_
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# {'n_estimators': 25,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_depth': 40}

# %% [markdown]
# Evaluation on test dataset

# %%
# Use the best model to make predictions
y_prediction = best_rfr.predict(X_test)

# Evaluate the performance of the best model on test dataset
r2 = r2_score(y_test, y_prediction)
adj_r2 = adjusted_r2_score(y_test, y_prediction, X_train.shape[0])
mae = mean_absolute_error(y_test, y_prediction)
mse = mean_squared_error(y_test, y_prediction)
rmse = sqrt(mse)


print(f"Adjusted R²: {adj_r2}")
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
# Out:
# R²: 0.9877971891008454
# MAE: 1036553.9616402123
# MSE: 4450133832145.285
# RMSE: 2109534.0319950483

# %% [markdown]
# Visualise model prediction performance

# %%
sns.scatterplot(x=y_test, y=y_prediction)
# Out:
# <Axes: xlabel='value_eur'>

# %%
sns.regplot(x=y_test, y=y_prediction, line_kws=dict(color="r"))
# Out:
# <Axes: xlabel='value_eur'>

# %% [markdown]
# Plot feature importance

# %%
# Get feature importances from the trained model
feature_importances = best_rfr.feature_importances_

# Get feature names from your dataset (assuming you have X_train available)
feature_names = X_train.columns

# Create a DataFrame for easier plotting
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances using Seaborn and Matplotlib
sns.barplot(x='Importance', y='Feature', data=importance_df)
# Out:
# <Axes: xlabel='Importance', ylabel='Feature'>
